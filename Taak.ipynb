# %% [markdown]
# ## De applicatie
# ### De delen van Streamlit zijn in commentaar gezet

# %%
# import streamlit as st
from itertools import permutations

# Function to solve the cryptarithmetic puzzle
def solve_cryptarithmetic(first_factor, second_factor, result, operation):
    # Combine all three parts into a single puzzle with the selected operation
    if operation == "+":
        puzzle = f"{first_factor} + {second_factor} = {result}"
    elif operation == "-":
        puzzle = f"{first_factor} - {second_factor} = {result}"
    elif operation == "*":
        puzzle = f"{first_factor} * {second_factor} = {result}"
    elif operation == "/":
        puzzle = f"{first_factor} / {second_factor} = {result}"
    else:
        return None  # Unsupported operation

    # Extract unique letters from the puzzle
    letters = set(filter(str.isalpha, puzzle))

    # Generate permutations of digits for the letters (0-9)
    digit_permutations = permutations(range(10), len(letters))

    # Checks every expression created in the map to see if it is correct
    # The map contains a dictionary with the key-value pairs of letters and numbers
    for perm in digit_permutations:
        digit_map = dict(zip(letters, perm))
        if evaluate_expression(puzzle, digit_map, operation):
            return digit_map

    return None

# Function to evaluate the expression with the digit mapping
def evaluate_expression(expression, digit_map, operation):
    # Replace letters with digits from the digit_map in the expression, this way it becomes a mathematical expression instead of words
    for letter, digit in digit_map.items():
        expression = expression.replace(letter, str(digit))

    # Split the expression into operands and evaluate based on the selected operation, strip off whitespace
    left_operand, right_operand = expression.split('=')
    left_operand = left_operand.strip()
    right_operand = right_operand.strip()

    # Check if the mathematical expression is correct, if so, return True
    try:
        if operation == "+":
            return eval(left_operand) == eval(right_operand)
        elif operation == "-":
            return eval(left_operand) == eval(right_operand)
        elif operation == "*":
            return eval(left_operand) == eval(right_operand)
        elif operation == "/":
            return eval(left_operand) == eval(right_operand)
        else:
            return False
    except:
        return False

# Custom function to format the equation with values
def format_equation_with_values(first_factor, second_factor, result, operation, solution):
    formatted_equation = ""
    if operation == "+":
        first_number = "".join([str(solution[char]) for char in first_factor])
        second_number = "".join([str(solution[char]) for char in second_factor])
        result_number = "".join([str(solution[char]) for char in result])
        formatted_equation = f"{first_number} + {second_number} = {result_number}"
    elif operation == "-":
        formatted_equation = f"{solution[first_factor[0]]}{solution[first_factor[1]]} - {solution[second_factor[0]]}{solution[second_factor[1]]} = {solution[result[0]]}{solution[result[1]]}{solution[result[2]]}"
    elif operation == "*":
        first_number = "".join([str(solution[char]) for char in first_factor])
        second_number = "".join([str(solution[char]) for char in second_factor])
        result_number = "".join([str(solution[char]) for char in result])
        formatted_equation = f"{first_number} * {second_number} = {result_number}"
    elif operation == "/":
        formatted_equation = f"{solution[first_factor[0]]}{solution[first_factor[1]]} / {solution[second_factor[0]]}{solution[second_factor[1]]} = {solution[result[0]]}{solution[result[1]]}{solution[result[2]]}{solution[result[3]]}"
    return formatted_equation

# Streamlit UI
# st.title("Cryptarithmetic Puzzle Solver")
print("Cryptarithmetic Puzzle Solver")


# first_factor = st.text_input("Enter the first factor (e.g., 'TO'):")
# second_factor = st.text_input("Enter the second factor (e.g., 'GO'):")
# result = st.text_input("Enter the result (e.g., 'OUT'):")
# operation = st.selectbox("Select the arithmetic operation:", ["+", "-", "*", "/"])
first_factor = input("Enter the first factor (e.g., 'TO'):")
second_factor = input("Enter the second factor (e.g., 'GO'):")
result = input("Enter the result (e.g., 'OUT'):")
operation = input("Enter the arithmetic operation: ('+', '-', '*', '/')")

# if st.button("Solve Puzzle"):
if not first_factor or not second_factor or not result:
    # st.error("Please enter all three parts of the puzzle.")
    print("Please enter all three parts of the puzzle.")
elif operation not in ["+", "-", "*", "/"]:
    # st.error("Please select a valid arithmetic operation.")
    print("Please select a valid arithmetic operation.")
else:
    solution = solve_cryptarithmetic(first_factor, second_factor, result, operation)

    if solution:
        # st.success("Solution found:")
        print("Solution found:")


        # Format the equation with values from the solution
        formatted_equation = format_equation_with_values(first_factor, second_factor, result, operation, solution)

        # Display the equation as it was filled in
        # st.write(f"{first_factor} {operation} {second_factor} = {result}")
        print(f"{first_factor} {operation} {second_factor} = {result}")


        # Display the formatted equation with numbers filled in
        # st.write(f"{formatted_equation}")
        print(f"{formatted_equation}")

        # Display the letter-number pairs
        # st.write(f"Letter-Number Mapping:")
        print(f"Letter-Number Mapping:")
        for letter, digit in solution.items():
            # st.write(f"{letter} = {digit}")
            print(f"{letter} = {digit}")

    else:
        # st.error("No solution found.")
        print("No solution found.")
# Out:
# Cryptarithmetic Puzzle Solver
# Solution found:
# TO + GO = OUT
# 21 + 81 = 102
# Letter-Number Mapping:
# O = 1
# G = 8
# T = 2
# U = 0

# %% [markdown]
# # Raportering
#
# ### Inhoud
# - Inleiding
# - Uitvoering
# - Gebruik van GenAI tools
# - Conclusie
#
# ### Inleiding
# Voor deze opdracht was het de bedoeling dat we een cryptarithmatic puzzle zouden maken waarbij de gebruiker zelf kan ingeven welke puzzel hij wilt laten oplossen. Daarna moeten de constraints en de oplossing automatisch worden uitgezocht. Als deze gevonden zijn, wordt de oplossing van de puzzel afgedrukt.
# Het was de bedoeling dat dit alles mooi samenkomt in een Streamlit applicatie, wat ook gelukt is.
#
# ### Uitvoering
# Voor de uitvoering leek het mij interessant om te kijken of je de volledige applicatie zou kunnen schrijven door een AI chatbot informatie te geven en bij te sturen.
# Om te beginnen heb ik gevraagd aan ChatGPT of de AI een cryptarithmatic puzzle kende. Bij het antwoord kreeg ik het voorbeeld van "SEND + MORE = MONEY", waarna ik vroeg om dit flexibeler te maken met user input.
# In eerste instantie werkte het niet, maar na wat bijsturen kwam het toch tot een werkende oplossing, weliswaar enkel voor optellingen.
#
# Toen de basisfunctie werkte, heb ik gevraagd om het om te zetten naar een streamlit applicatie. Dit lukte eigenlijk zo goed als meteen, wat ik toeschrijf aan de simpliciteit van Streamlit.
# Eens dit redelijk goed was afgewerkt, heb ik de AI de applicatie laten uitbreiden om alle aritmetische bewerkingen te kunnen laten uitvoeren.
# Dit bleek moeilijker te zijn, en de AI had redelijk veel bijsturing nodig om voor de verschillende bewerkingen allemaal tot de juiste uitkomst te komen.
#
# Toen de bewerkingen leken te werken heb ik de AI de opdracht gegeven om de uitkomst mooi af te printen volgens het format dat ik doorstuurde.
# Hier duurde het weer een tijdje voor het tot een min of meer juiste oplossing kwam, waarna ik zelf wat code heb aangepast. De aangepaste code heb ik dan gebruikt om de laatste foutjes uit de berekeningen en het getoonde antwoord te halen. Ten slotte heb ik ook de commentaar in de code zelf uitgebreid om de werkwijze te verduidelijken.
#
# ### Gebruik van GenAI tools
# Ondanks dat het werd afgeraden om alles met AI te doen, leek het mij een leuke opdracht om te kijken hoe ver ik kon geraken met (zo goed als) enkel door AI gegenereerde code.
#
# Uit ervaring bleek dat deze code vaak nog vol fouten zat, en ook bij dit was dat weer het geval. Echter ben ik wel tot een goed werkende oplossing geraakt door zelf kritisch naar de code te kijken, en de foute delen - indien mogelijk - te laten verbeteren door de AI.
# Ik ben uiteindelijk tot de oplossing gekomen waarbij het programmeren bijna volledig door AI is gedaan, 100% door AI is me echter niet gelukt.
#
# Ik ben er eigenlijk op twee manieren door verrast. Enerzijds ben ik verrast dat de AI tot een oplossing is kunnen komen, weliswaar na veel bijsturingen. Anderzijds ben ik verrast dat het toch nog zo lang heeft geduurd alvorens ik tot een correcte oplossing kwam.
#
# ### Conclusie
# Hoewel de opdracht een relatief kleine uitbreiding is op de oefeningen die we gezien hebben, bleek het toch niet zo evident te zijn om tot een flexibelere oplossing te komen. Uiteindelijk is dit met behulp van ChatGPT wel gelukt en ben ik tot een relatief simpele oplossing kunnen komen.
#
# Het was leuk om eens wat vrijheid te hebben voor het gebruik van GenAI tools, en ik vond het interessant om te zien hoe ver deze tools al zijn gekomen op relatief korte tijd.
# De opdracht zelf was ook een leuke uitdaging. Zeker aangezien er zoveel verschillende oplossingen en manieren van aanpak mogelijk zijn.
